# %%
from CoDIAC import mutations

Nterm_offset = 0
Cterm_offset = -1
ref_fastaFile = 'Data/Uniprot_Reference/SH2_IPR000980.fasta'

# %%
#OMIM mutations
api_key = '****'
mutations.OMIM_mutations('SH2_IPR000980_uniprot_reference.csv', api_key, ref_fastaFile,
                         'SH2_IPR000980_OMIMmut.fea', 'SH2', Nterm_offset, Cterm_offset)
# Out:
# A6NKC9
# O00459
# O14492
# O14508
# O14512
# O14543
# O14544
# O14796
# O15357
# O15524
# O43639
# O60674
# O60880
# O75159
# O75791
# O75815
# P00519
# P06239
# P06241
# P07332
# P07947
# P07948
# P08631
# P09769
# P12931
# P15498
# P15882
# P16333
# P16591
# P16885
# P19174
# P20936
# P23458
# P27986
# P29350
# P29353
# P29597
# P40763
# P41240
# P42224
# P42226
# P42229
# P42679
# P42680
# P42681
# P42684
# P42685
# P43403
# P43405
# P46108
# P46109
# P51451
# P51692
# P51813
# P52333
# P52630
# P52735
# P52757
# P62993
# P78314
# P98077
# Q06124
# Q06187
# Q08881
# Q13094
# Q13239
# Q13322
# Q13588
# Q13671
# Q13882
# Q14449
# Q14451
# Q14765
# Q15464
# Q5SQS7
# Q5VZ18
# Q63HR2
# Q68CZ2
# Q6S5L8
# Q6ZV89
# Q7KZ85
# Q7M4L6
# Q7Z4S9
# Q7Z7G1
# Q8IZW8
# Q8N5H7
# Q8TB24
# Q8TC17
# Q8WV28
# Q8WXH5
# Q8WYP3
# Q92529
# Q92569
# Q92835
# Q96IW2
# Q96JZ2
# Q9BRG2
# Q9H3Y6
# Q9H6Q3
# Q9H788
# Q9HBL0
# Q9NP31
# Q9NRF2
# Q9NSE2
# Q9UGK3
# Q9UKW4
# Q9ULZ2
# Q9UN19
# Q9UQQ2
# ...

# %%
#PDB Mutations
PDB_refFile = ('SH2_IPR000980_PDB_reference.csv')
output_featureFile = 'SH2_IPR000980_PDBmut.fea'
mutations.PDB_mutations(PDB_refFile, ref_fastaFile, output_featureFile, 'SH2', Nterm_offset, Cterm_offset)
# Out:
# 7M6T
# 2FO0 N363D;E513Q
# {2: ['SH2', '125', '217']}
# 5MO4 I315T;N363D
# {2: ['SH2', '125', '217']}
# 1AOT
# 1AOU
# 1G83 S239C;S240C
# {2: ['SH2', '147', '246']}
# 1QCF
# 2C0I E523Q;E524Q;I525Q
# {2: ['SH2', '142', '241']}
# 2C0O E523Q;E524Q;I525Q
# {2: ['SH2', '142', '241']}
# 2C0T E523Q;E524Q;I525Q
# {2: ['SH2', '142', '241']}
# 3VRY
# 3VRZ
# 3VS0
# 3VS1
# 3VS2
# 3VS3
# 3VS4
# 3VS5
# 3VS6
# 3VS7
# 4LUD E523Q;E524Q;I525Q
# {2: ['SH2', '142', '241']}
# 4LUE E523Q;E524Q;I525Q
# {2: ['SH2', '142', '241']}
# 5H09
# 5H0B
# 5H0E
# 5H0G
# 5H0H
# 7UY0 E524Q;E525P;I526G
# {2: ['SH2', '142', '241']}
# 7UY0 E524Q;E525P;I526G
# {2: ['SH2', '142', '241']}
# 7UY3 E524Q;E525P;I526G
# {2: ['SH2', '142', '241']}
# 1A1A
# 1KSW
# 4F59 V183T;A188C;L206K
# {1: ['SH2', '149', '248']}
# 4F5A V183T;A188C;L206K
# {1: ['SH2', '149', '248']}
# 4F5B V183T;A188C;L206K
# {1: ['SH2', '149', '248']}
# 4K11
# 7YQE A248C
# {2: ['SH2', '149', '248']}
# 4EY0
# 6WAX
# 6WAY
# 3HHM
# 3HIZ
# 4WAF
# 5GJI
# 5UK8
# 7CIO
# ...

# %%
#gnomAD mutations
csvfiles_dir = './gnomAD/VariantFiles/'
downloads_path = '/Downloads'
gnomAD_mutations(ref_fastaFile, downloads_path, csvfiles_dir, 'SH2_IPR000980_gnomADmut.fea', Nterm_offset, Cterm_offset)
# Out:
# ENSG00000167193
# ENSG00000027869
# ENSG00000134215
# ENSG00000106070
# ENSG00000198574
# ENSG00000166888
# ENSG00000105639
# ENSG00000197943
# ENSG00000197943
# ENSG00000070190
# ENSG00000111816
# ENSG00000120833
# ENSG00000151422
# ENSG00000185634
# ENSG00000115085
# ENSG00000115085
# ENSG00000178217
# ENSG00000095585
# ENSG00000125508
# ENSG00000189152
# ENSG00000165025
# ENSG00000165025
# ENSG00000010671
# ENSG00000124181
# ENSG00000124181
# ENSG00000105397
# ENSG00000128656
# ENSG00000102010
# ENSG00000035720
# ENSG00000135605
# ENSG00000105251
# ENSG00000109684
# ENSG00000180008
# ENSG00000074966
# ENSG00000158092
# ENSG00000171150
# ENSG00000138606
# ENSG00000160691
# ENSG00000131746
# ENSG00000170677
# ENSG00000101082
# ENSG00000176105
# ENSG00000137936
# ENSG00000178188
# ENSG00000007264
# ENSG00000109111
# ENSG00000115415
# ENSG00000100599
# ENSG00000087266
# ENSG00000096968
# ENSG00000169291
# ENSG00000162434
# ENSG00000145675
# ENSG00000145675
# ENSG00000111679
# ...
